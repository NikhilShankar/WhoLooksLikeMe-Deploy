# %%
from ClassificationModel import ClassificationModel


large_model_path = "../FinalizedModelsForAWS/WLLM-Model-Nikhil-L2-12-10-01-24/best_model.keras"
names_csv_path = "../FinalizedModelsForAWS/WLLM-Model-0001/WLLM-Model-Nikhil-L2-12-10-01-24.csv"
image_dataset_path = "../dataset"
predictions_save_path = "../predictions"

classificationModel = ClassificationModel(large_model_path, names_csv_path)
predicted_personality, scores = classificationModel.predict_single_image("../test_images/leo.jpg")
display(predicted_personality)
display(scores)
# Out:
# Embedding model created using layer: 'embedding'.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 'tom hardy'
#                 Class Name  Class Index  Prediction Score
# 0                tom hardy           46      9.191430e-01
# 1           tom hiddleston           47      5.385305e-02
# 2                tom ellis           45      6.758695e-03
# 3             mark ruffalo           17      4.904074e-03
# 4               rami malek           31      4.079277e-03
# 5           richard harmon           33      2.922510e-03
# 6        leonardo dicaprio            7      2.330294e-03
# 7             pedro alonso           29      1.920568e-03
# 8            stephen amell           42      1.631501e-03
# 9              miley cyrus           21      5.418637e-04
# 10     neil patrick harris           28      4.438816e-04
# 11          robert de niro           35      3.076092e-04
# 12          kiernen shipka            5      2.356954e-04
# ...

# %%
predicted_personality, scores = classificationModel.predict_single_image("../test_images/pedro.jpg")
display(predicted_personality)
display(scores)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 'pedro alonso'
#                 Class Name  Class Index  Prediction Score
# 0             pedro alonso           29      8.431427e-01
# 1           tom hiddleston           47      1.241327e-01
# 2           richard harmon           33      1.431031e-02
# 3         wentworth miller           51      8.146111e-03
# 4              josh radnor            1      2.532983e-03
# 5               rami malek           31      2.442593e-03
# 6         robert downey jr           36      1.372927e-03
# 7           kiernen shipka            5      1.292782e-03
# 8             mark ruffalo           17      1.041091e-03
# 9              tom holland           48      4.965948e-04
# 10          robert de niro           35      2.884046e-04
# 11     neil patrick harris           28      2.219864e-04
# 12           stephen amell           42      1.506773e-04
# 13            lionel messi           10      1.044737e-04
# ...

# %%
predicted_personality, scores = classificationModel.predict_single_image("../test_images/tom4.jpg")
display(predicted_personality)
display(scores)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 'tom ellis'
#                 Class Name  Class Index  Prediction Score
# 0                tom ellis           45      2.814454e-01
# 1             pedro alonso           29      2.661044e-01
# 2         robert downey jr           36      1.863533e-01
# 3           tom hiddleston           47      6.428955e-02
# 4                tom hardy           46      4.850987e-02
# 5             mark ruffalo           17      4.756176e-02
# 6           robert de niro           35      2.706410e-02
# 7              tom holland           48      2.673996e-02
# 8              josh radnor            1      1.741957e-02
# 9             lionel messi           10      1.726331e-02
# 10            keanu reeves            4      5.946924e-03
# 11              tom cruise           44      3.530971e-03
# 12          richard harmon           33      2.235574e-03
# 13              rami malek           31      9.388160e-04
# ...

# %%
predicted_personality, scores = classificationModel.predict_single_image("../test_images/miley.jpg")
display(predicted_personality)
display(scores)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 'miley cyrus'
#                 Class Name  Class Index  Prediction Score
# 0              miley cyrus           21      5.014185e-01
# 1   shakira isabel mebarak           40      3.161096e-01
# 2         katharine mcphee            2      8.590907e-02
# 3           natalie dormer           26      4.660374e-02
# 4            margot robbie           14      1.535735e-02
# 5            sophie turner           41      1.060882e-02
# 6       katherine langford            3      7.187264e-03
# 7            maria pedraza           15      6.976450e-03
# 8             nadia hilker           25      4.248176e-03
# 9            lili reinhart            8      2.555585e-03
# 10      scarlett johansson           38      1.145759e-03
# 11          kiernen shipka            5      4.190025e-04
# 12                 rihanna           34      2.860086e-04
# 13     sarah wayne callies           37      2.561499e-04
# ...

# %%
classificationModel.evaluate_on_test_folder("../TrainingDataImages/WLLM-Model-Nikhil-L2-12-10-01-24/test")
# Out:
# Found 208 images belonging to 52 classes.
# c:\Users\DELL\Desktop\Conestoga\AIML\FOML-FinalProject\WhoLooksLikeMe\venv\tensorflow_facenet\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 264ms/step
#                         precision    recall  f1-score     support
# johnny depp              0.500000  0.500000  0.500000    4.000000
# josh radnor              0.600000  0.750000  0.666667    4.000000
# katharine mcphee         1.000000  0.500000  0.666667    4.000000
# katherine langford       1.000000  1.000000  1.000000    4.000000
# keanu reeves             1.000000  1.000000  1.000000    4.000000
# ...

# %%
from WLLMModelLoader import WLLMModelLoader
large_model_path = "../SavedTrainingData/savedmodels/WLLM-Model-Nikhil-L2-12-10-01-24/best_model.keras"

modelLoader = WLLMModelLoader(large_model_path)
print(len(modelLoader.model.layers))
# Out:
# Embedding model created using layer: 'embedding'.
# 314
